# %%
# %matplotlib notebook
import sys
sys.path.append('../source/')
from trader import Trader
from entrymodels import ABC04
from exitmodels import StopOrTarget
from datetime import datetime, timedelta

# %%
end = datetime.today()
start = end - timedelta(12 * 30)

# %%
trader = Trader(risk_size=200, target_size=800, capital=20000, fees=5.5)

# %%
trader.loadportfolio(portfolio=['ITSA4.SA', 'MGLU3.SA'], start=start, end=end)

# %%
trader.backtest(ABC04, StopOrTarget, updaterisk=False, trail=False)
# Out:
# 2020-01-06 00:00:00: MGLU3.SA entry=12.34, stop=12.06
# Loss...
# 2020-01-06 00:00:00: MGLU3.SA price=12.06
# 2020-01-08 00:00:00: MGLU3.SA entry=12.34, stop=12.06
# Profit!
# 2020-01-13 00:00:00: MGLU3.SA price=13.46
# 2020-01-17 00:00:00: ITSA4.SA entry=13.56, stop=13.37
# Loss...
# 2020-01-20 00:00:00: ITSA4.SA price=13.37
# 2020-01-20 00:00:00: MGLU3.SA entry=13.62, stop=13.06
# 2020-01-29 00:00:00: MGLU3.SA entry=14.28, stop=13.43
# 2020-02-04 00:00:00: MGLU3.SA entry=14.53, stop=13.75
# Loss...
# 2020-02-07 00:00:00: MGLU3.SA price=13.43
# Loss...
# 2020-02-07 00:00:00: MGLU3.SA price=13.75
# Loss...
# 2020-02-10 00:00:00: MGLU3.SA price=13.06
# 2020-02-18 00:00:00: ITSA4.SA entry=13.18, stop=12.99
# Loss...
# 2020-02-18 00:00:00: ITSA4.SA price=12.99
# 2020-03-24 00:00:00: MGLU3.SA entry=9.03, stop=7.38
# 2020-03-31 00:00:00: ITSA4.SA entry=8.88, stop=8.46
# 2020-03-31 00:00:00: MGLU3.SA entry=10.52, stop=9.4
# Loss...
# 2020-04-01 00:00:00: ITSA4.SA price=8.46
# Loss...
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-27 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        14.4516
# total_trades                                            35
# open_trades                                              4
# pnl                                                3762.23
# pnl_percent                                        18.8112
# batting_avg                                       0.322581
# sharpe                                              3.9097
# liquid_cap                                          705.81
# total_cap                                            24919
# Name: summary, dtype: object

# %%
trader.history()
# Out:
#    entry_date    ticker  entry entry_vol   stop target  status   exit  \
# 0  2020-01-06  MGLU3.SA  12.34       714  12.06  13.46    sold  12.06
# 1  2020-01-08  MGLU3.SA  12.34       714  12.06  13.46    sold  13.46
# 2  2020-01-17  ITSA4.SA  13.56      1053  13.37  14.32    sold  13.37
# 3  2020-01-20  MGLU3.SA  13.62       357  13.06  15.86    sold  13.06
# 4  2020-01-29  MGLU3.SA  14.28       235  13.43  17.68    sold  13.43
# 5  2020-02-04  MGLU3.SA  14.53       256  13.75  17.65    sold  13.75
# 6  2020-02-18  ITSA4.SA  13.18      1053  12.99  13.94    sold  12.99
# 7  2020-03-24  MGLU3.SA   9.03       121   7.38  15.63    sold   15.8
# 8  2020-03-31  ITSA4.SA   8.88       476   8.46  10.56    sold   8.46
# 9  2020-03-31  MGLU3.SA  10.52       179   9.40     15    sold   9.35
# 10 2020-05-05  MGLU3.SA  12.93       180  11.82  17.37    sold  17.37
# 11 2020-05-18  ITSA4.SA   8.56       465   8.13  10.28    sold  10.29
# ...

# %%
trader.performance(benchmark='BOVA11.SA')
# Out:
# <img src="data:image/png;base64,..." width="938">

# %%
trader.plottrades('MGLU3.SA')
# Out:
# <div>
#
#
#             <div id="2bb212d3-6563-489b-b01a-4fd189f1e163" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2bb212d3-6563-489b-b01a-4fd189f1e163")) {
#                     Plotly.newPlot(
#                         '2bb212d3-6563-489b-b01a-4fd189f1e163',
# ...

# %% [markdown]
# ## Model ABC + 4 SMA criteria

# %%
ABC04.selectCriteria = '4SMA'
Trader._portfolio = trader._portfolio.copy()
Trader._period = [start, end]

# %%
trader = Trader(risk_size=200, target_size=800, capital=20000, fees=5.5)
trader.loadportfolio(portfolio=['ITSA4.SA', 'MGLU3.SA'], start=start, end=end)

# %%
trader.backtest(ABC04, StopOrTarget, trail=False, updaterisk=False)
# Out:
# 2020-06-15 00:00:00: MGLU3.SA entry=16.27, stop=15.62
# Loss...
# 2020-06-15 00:00:00: MGLU3.SA price=15.62
# 2020-06-30 00:00:00: MGLU3.SA entry=17.61, stop=17.04
# 2020-07-09 00:00:00: ITSA4.SA entry=10.23, stop=9.96
# Profit!
# 2020-07-09 00:00:00: MGLU3.SA price=19.89
# Loss...
# 2020-07-14 00:00:00: ITSA4.SA price=9.96
# 2020-07-20 00:00:00: ITSA4.SA entry=10.34, stop=10.12
# 2020-07-20 00:00:00: MGLU3.SA entry=20.6, stop=19.77
# Loss...
# 2020-07-23 00:00:00: MGLU3.SA price=19.77
# 2020-07-27 00:00:00: ITSA4.SA entry=10.62, stop=10.21
# Loss...
# 2020-08-04 00:00:00: ITSA4.SA price=10.21
# Loss...
# 2020-08-05 00:00:00: ITSA4.SA price=10.12
# 2020-08-24 00:00:00: MGLU3.SA entry=22.18, stop=21.53
# 2020-09-01 00:00:00: MGLU3.SA entry=23.66, stop=23.08
# Loss...
# 2020-09-03 00:00:00: MGLU3.SA price=23.08
# Loss...
# 2020-09-04 00:00:00: MGLU3.SA price=21.53
# 2020-10-19 00:00:00: MGLU3.SA entry=26.06, stop=24.99
# Loss...
# 2020-10-28 00:00:00: MGLU3.SA price=24.8
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-27 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        5.90909
# total_trades                                            13
# open_trades                                              2
# pnl                                               -1296.07
# pnl_percent                                       -6.48035
# batting_avg                                      0.0909091
# sharpe                                             3.80123
# liquid_cap                                         2721.11
# total_cap                                          18963.1
# Name: summary, dtype: object

# %%
trader.history()
# Out:
#    entry_date    ticker  entry entry_vol   stop target  status   exit  \
# 0  2020-06-15  MGLU3.SA  16.27       308  15.62  18.87    sold  15.62
# 1  2020-06-30  MGLU3.SA  17.61       351  17.04  19.89    sold  19.89
# 2  2020-07-09  ITSA4.SA  10.23       741   9.96  11.31    sold   9.96
# 3  2020-07-20  ITSA4.SA  10.34       909  10.12  11.22    sold  10.12
# 4  2020-07-20  MGLU3.SA  20.60       241  19.77  23.92    sold  19.77
# 5  2020-07-27  ITSA4.SA  10.62       488  10.21  12.26    sold  10.21
# 6  2020-08-24  MGLU3.SA  22.18       308  21.53  24.78    sold  21.53
# 7  2020-09-01  MGLU3.SA  23.66       345  23.08  25.98    sold  23.08
# 8  2020-10-19  MGLU3.SA  26.06       187  24.99  30.34    sold   24.8
# 9  2020-11-09  MGLU3.SA  27.71       165  26.50  32.55    sold   26.5
# 10 2020-11-24  ITSA4.SA  10.98       588  10.64  12.34    sold  10.64
# 11 2020-12-03  ITSA4.SA  11.14       833  10.90   12.1  bought    NaN
# ...

# %%
trader.plottrades('MGLU3.SA')
# Out:
# <div>
#
#
#             <div id="56a2837a-9dc8-4d75-be6c-0625198f9c09" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("56a2837a-9dc8-4d75-be6c-0625198f9c09")) {
#                     Plotly.newPlot(
#                         '56a2837a-9dc8-4d75-be6c-0625198f9c09',
# ...

# %% [markdown]
# ## Model ABC + 4 SMA criteria

# %%
ABC04.selectCriteria = '4SMA'
ABC04.stop = {'position': 'C', 'factor': 1.5}

# %%
trader = Trader(risk_size=200, target_size=800, capital=20000, fees=5.5)

# %%
trader.backtest(ABC04, StopOrTarget, trail=False, updaterisk=False)
# Out:
# 2020-06-15 00:00:00: MGLU3.SA entry=16.27, stop=15.294999999999998
# 2020-06-30 00:00:00: MGLU3.SA entry=17.61, stop=16.755
# 2020-07-09 00:00:00: ITSA4.SA entry=10.23, stop=9.825000000000001
# Profit!
# 2020-07-10 00:00:00: MGLU3.SA price=20.17
# 2020-07-20 00:00:00: ITSA4.SA entry=10.34, stop=10.009999999999998
# 2020-07-20 00:00:00: MGLU3.SA entry=20.6, stop=19.354999999999997
# Profit!
# 2020-07-20 00:00:00: MGLU3.SA price=21.03
# Loss...
# 2020-07-24 00:00:00: MGLU3.SA price=19.35
# 2020-07-27 00:00:00: ITSA4.SA entry=10.62, stop=10.005000000000003
# Loss...
# 2020-08-12 00:00:00: ITSA4.SA price=10.01
# Loss...
# 2020-08-12 00:00:00: ITSA4.SA price=10.01
# Loss...
# 2020-08-17 00:00:00: ITSA4.SA price=9.83
# 2020-08-24 00:00:00: MGLU3.SA entry=22.18, stop=21.205000000000002
# 2020-09-01 00:00:00: MGLU3.SA entry=23.66, stop=22.79
# Loss...
# 2020-09-03 00:00:00: MGLU3.SA price=22.79
# Loss...
# 2020-09-04 00:00:00: MGLU3.SA price=21.21
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-27 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                             15
# total_trades                                            14
# open_trades                                              4
# pnl                                                  -52.7
# pnl_percent                                        -0.2635
# batting_avg                                            0.2
# sharpe                                             3.87158
# liquid_cap                                          318.34
# total_cap                                          20269.7
# Name: summary, dtype: object

# %%
trader.performance('BOVA11.SA')
# Out:
# <img src="data:image/png;base64,..." width="843">

# %% [markdown]
# ## Model ABC

# %%
ABC04.stop = {'position': 'C', 'factor': 1.5}
ABC04.selectCriteria = None

# %%
trader.backtest(ABC04, StopOrTarget, trail=False, updaterisk=False)
# Out:
# Create portfolio before backtesting...

# %%
trader.summary()
# Out:
# period          [2019-12-27 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        27.4643
# total_trades                                            35
# open_trades                                              7
# pnl                                                6242.04
# pnl_percent                                        31.2102
# batting_avg                                       0.428571
# sharpe                                             3.85955
# liquid_cap                                          1500.7
# total_cap                                          27555.5
# Name: summary, dtype: object

# %%
trader.plottrades('MGLU3.SA')
# Out:
# <div>
#
#
#             <div id="0f60d811-07eb-4ecb-acac-03a607adf7b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0f60d811-07eb-4ecb-acac-03a607adf7b8")) {
#                     Plotly.newPlot(
#                         '0f60d811-07eb-4ecb-acac-03a607adf7b8',
# ...

# %%
trader.performance(benchmark='BOVA11.SA')
# Out:
# <img src="data:image/png;base64,..." width="869.5">

# %% [markdown]
# ## Model ABC - 1.5C

# %%
ABC04.stop = {'position': 'C', 'factor': 1.5}
ABC04.selectCriteria = None
trader = Trader(risk_size=100, target_size=400, capital=20000, fees=5.5)

# %%
trader.loadportfolio(portfolio=['ITSA4.SA', 'MGLU3.SA', 'ETER3.SA'], start=start, end=end)

# %%
trader.reset()
trader.backtest(ABC04, StopOrTarget, trail=False, updaterisk=False)
# Out:
# 2020-01-06 00:00:00: MGLU3.SA entry=12.34, stop=11.920000000000002
# 2020-01-08 00:00:00: MGLU3.SA entry=12.34, stop=11.920000000000002
# 2020-01-17 00:00:00: ITSA4.SA entry=13.56, stop=13.274999999999999
# 2020-01-20 00:00:00: MGLU3.SA entry=13.62, stop=12.780000000000001
# 2020-01-20 00:00:00: ETER3.SA entry=7.31, stop=5.255000000000001
# Loss...
# 2020-01-21 00:00:00: ITSA4.SA price=13.27
# Profit!
# 2020-01-21 00:00:00: MGLU3.SA price=14.02
# Profit!
# 2020-01-21 00:00:00: MGLU3.SA price=14.02
# 2020-01-29 00:00:00: MGLU3.SA entry=14.28, stop=13.004999999999999
# 2020-02-04 00:00:00: MGLU3.SA entry=14.53, stop=13.36
# Loss...
# 2020-02-10 00:00:00: MGLU3.SA price=13.0
# Loss...
# 2020-02-10 00:00:00: MGLU3.SA price=13.36
# 2020-02-12 00:00:00: ETER3.SA entry=6.75, stop=5.895
# 2020-02-18 00:00:00: ITSA4.SA entry=13.18, stop=12.895
# Loss...
# 2020-02-18 00:00:00: ITSA4.SA price=12.89
# Loss...
# 2020-02-21 00:00:00: ETER3.SA price=5.89
# Loss...
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        25.1569
# total_trades                                            62
# open_trades                                             11
# pnl                                                5498.31
# pnl_percent                                        27.4916
# batting_avg                                       0.411765
# sharpe                                             4.25208
# liquid_cap                                         9523.65
# total_cap                                          26322.1
# Name: summary, dtype: object

# %%
trader.summary('ETER3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                           20.5
# total_trades                                            23
# open_trades                                              3
# pnl                                                2477.41
# pnl_percent                                        12.3871
# batting_avg                                           0.45
# sharpe                                             4.04172
# Name: summary, dtype: object

# %%
trader.summary('MGLU3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        28.4211
# total_trades                                            21
# open_trades                                              2
# pnl                                                2092.44
# pnl_percent                                        10.4622
# batting_avg                                       0.421053
# sharpe                                             4.08979
# Name: summary, dtype: object

# %%
trader.summary('ITSA4.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                          27.75
# total_trades                                            18
# open_trades                                              6
# pnl                                                 928.46
# pnl_percent                                         4.6423
# batting_avg                                       0.333333
# sharpe                                             4.86482
# Name: summary, dtype: object

# %%
trader.performance(benchmark='BOVA11.SA')
# Out:
# <img src="data:image/png;base64,..." width="880">

# %%
trader.plottrades('ETER3.SA')
# Out:
# <div>
#
#
#             <div id="c9064be1-bf4d-437b-ac92-78d01f9f5045" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c9064be1-bf4d-437b-ac92-78d01f9f5045")) {
#                     Plotly.newPlot(
#                         'c9064be1-bf4d-437b-ac92-78d01f9f5045',
# ...

# %%
trader.plottrades('ITSA4.SA')
# Out:
# <div>
#
#
#             <div id="6f57ba8e-7331-4a0f-8856-a358a19fc348" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f57ba8e-7331-4a0f-8856-a358a19fc348")) {
#                     Plotly.newPlot(
#                         '6f57ba8e-7331-4a0f-8856-a358a19fc348',
# ...

# %% [markdown]
# ## Model ABC - 1.5C

# %%
trader.reset()
ABC04.stop = {'position': 'C', 'factor': 1.5}
ABC04.selectCriteria = 'sma21'

# %%
trader.backtest(ABC04, StopOrTarget, trail=True, updaterisk=False)
# Out:
# 2020-02-04 00:00:00: MGLU3.SA entry=14.53, stop=13.36
# Loss...
# 2020-02-10 00:00:00: MGLU3.SA price=13.36
# 2020-03-31 00:00:00: MGLU3.SA entry=10.52, stop=8.84
# Loss...
# 2020-04-02 00:00:00: MGLU3.SA price=8.84
# 2020-05-05 00:00:00: MGLU3.SA entry=12.93, stop=11.265
# 2020-06-01 00:00:00: ETER3.SA entry=2.86, stop=2.5
# 2020-06-02 00:00:00: ITSA4.SA entry=9.44, stop=8.405000000000001
# 2020-06-09 00:00:00: MGLU3.SA entry=15.83, stop=14.014999999999999
# 2020-06-09 00:00:00: ETER3.SA entry=3.35, stop=2.8100000000000005
# 2020-06-15 00:00:00: MGLU3.SA entry=16.27, stop=15.294999999999998
# 2020-06-17 00:00:00: ITSA4.SA entry=9.93, stop=9.135000000000002
# 2020-06-26 00:00:00: ETER3.SA entry=3.76, stop=3.2950000000000004
# 2020-06-30 00:00:00: MGLU3.SA entry=17.61, stop=16.755
# 2020-07-02 00:00:00: ETER3.SA entry=3.66, stop=3.465
# Profit!
# 2020-07-08 00:00:00: ETER3.SA price=4.3
# Profit!
# 2020-07-08 00:00:00: ETER3.SA price=4.44
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        25.5938
# total_trades                                            42
# open_trades                                             10
# pnl                                                3523.56
# pnl_percent                                        17.6178
# batting_avg                                        0.40625
# sharpe                                             4.66933
# liquid_cap                                         8963.88
# total_cap                                          24187.3
# Name: summary, dtype: object

# %%
trader.summary('ETER3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        20.1538
# total_trades                                            16
# open_trades                                              3
# pnl                                                2226.97
# pnl_percent                                        11.1349
# batting_avg                                       0.538462
# sharpe                                             4.42205
# Name: summary, dtype: object

# %%
trader.summary('MGLU3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        25.4286
# total_trades                                            15
# open_trades                                              1
# pnl                                                1124.06
# pnl_percent                                         5.6203
# batting_avg                                       0.357143
# sharpe                                             4.18319
# Name: summary, dtype: object

# %%
trader.summary('ITSA4.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                           40.2
# total_trades                                            11
# open_trades                                              6
# pnl                                                 172.53
# pnl_percent                                        0.86265
# batting_avg                                            0.2
# sharpe                                             7.12314
# Name: summary, dtype: object

# %%
trader.plottrades('ITSA4.SA')
# Out:
# <div>
#
#
#             <div id="3d333036-31b4-4047-90d2-29af4f1e4ef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3d333036-31b4-4047-90d2-29af4f1e4ef2")) {
#                     Plotly.newPlot(
#                         '3d333036-31b4-4047-90d2-29af4f1e4ef2',
# ...

# %%
trader.plottrades('ETER3.SA')
# Out:
# <div>
#
#
#             <div id="614f04b0-0669-463d-a2a9-7f5f28ec8593" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("614f04b0-0669-463d-a2a9-7f5f28ec8593")) {
#                     Plotly.newPlot(
#                         '614f04b0-0669-463d-a2a9-7f5f28ec8593',
# ...

# %%
trader.plottrades('MGLU3.SA')
# Out:
# <div>
#
#
#             <div id="2960333c-9ed8-4c7e-9d0a-db21e8e6f0ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2960333c-9ed8-4c7e-9d0a-db21e8e6f0ce")) {
#                     Plotly.newPlot(
#                         '2960333c-9ed8-4c7e-9d0a-db21e8e6f0ce',
# ...

# %%
# trader.reset()
ABC04.stop = {'position': 'C', 'factor': 1.5}
ABC04.selectCriteria = 'sma21'
trader.loadportfolio(portfolio=['VALE3.SA', 'CSAN3.SA', 'UGPA3.SA'], start=start, end=end)

# %%
trader.backtest(ABC04, StopOrTarget, trail=False, updaterisk=False)
# Out:
# 2020-02-03 00:00:00: CSAN3.SA entry=81.41, stop=78.41
# Loss...
# 2020-02-10 00:00:00: CSAN3.SA price=78.41
# 2020-02-20 00:00:00: VALE3.SA entry=53.42, stop=51.455
# Loss...
# 2020-02-21 00:00:00: VALE3.SA price=51.0
# 2020-03-31 00:00:00: VALE3.SA entry=42.33, stop=37.62
# 2020-04-07 00:00:00: VALE3.SA entry=44.58, stop=37.335
# 2020-04-14 00:00:00: VALE3.SA entry=45.51, stop=41.489999999999995
# 2020-04-23 00:00:00: VALE3.SA entry=44.24, stop=40.94
# 2020-04-28 00:00:00: CSAN3.SA entry=60.73, stop=48.325
# 2020-04-28 00:00:00: UGPA3.SA entry=14.5, stop=10.809999999999999
# 2020-05-05 00:00:00: UGPA3.SA entry=14.71, stop=13.375
# 2020-05-06 00:00:00: CSAN3.SA entry=61.9, stop=56.035000000000004
# Loss...
# 2020-05-07 00:00:00: UGPA3.SA price=13.38
# 2020-05-15 00:00:00: VALE3.SA entry=49.26, stop=45.765
# 2020-05-25 00:00:00: UGPA3.SA entry=16.88, stop=14.795000000000002
# 2020-05-26 00:00:00: CSAN3.SA entry=65.41, stop=61.765
# Low capital...
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-30 00:00:00, 2020-12-23 00:00:00]
# avg_time_in                                          47.55
# total_trades                                            28
# open_trades                                              8
# pnl                                                3812.55
# pnl_percent                                        19.0627
# batting_avg                                            0.4
# sharpe                                             3.73701
# liquid_cap                                         3356.42
# total_cap                                          26537.2
# Name: summary, dtype: object

# %%
trader.summary('VALE3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        68.5333
# total_trades                                            17
# open_trades                                              2
# pnl                                                3372.21
# pnl_percent                                         16.861
# batting_avg                                       0.666667
# sharpe                                             3.42996
# Name: summary, dtype: object

# %%
trader.summary('CSAN3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                           27.8
# total_trades                                            11
# open_trades                                              1
# pnl                                                 949.39
# pnl_percent                                        4.74695
# batting_avg                                            0.4
# sharpe                                             3.74999
# Name: summary, dtype: object

# %%
trader.summary('UGPA3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                             24
# total_trades                                            13
# open_trades                                              6
# pnl                                                -739.82
# pnl_percent                                        -3.6991
# batting_avg                                              0
# sharpe                                                  -0
# Name: summary, dtype: object

# %%
trader.performance(benchmark='BOVA11.SA')
# Out:
# <img src="data:image/png;base64,..." width="872">

# %%
trader.plottrades('UGPA3.SA')
# Out:
# <div>
#
#
#             <div id="318a0cd4-c386-4420-a558-46f2361ad581" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("318a0cd4-c386-4420-a558-46f2361ad581")) {
#                     Plotly.newPlot(
#                         '318a0cd4-c386-4420-a558-46f2361ad581',
# ...

# %%
trader.plottrades('VALE3.SA')
# Out:
# <div>
#
#
#             <div id="75503941-a875-49cf-8b49-ee589af8aa2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("75503941-a875-49cf-8b49-ee589af8aa2d")) {
#                     Plotly.newPlot(
#                         '75503941-a875-49cf-8b49-ee589af8aa2d',
# ...

# %%
trader.plottrades('CSAN3.SA')
# Out:
# <div>
#
#
#             <div id="8dd8d270-357e-4ac6-aa2b-93aea07c2a86" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8dd8d270-357e-4ac6-aa2b-93aea07c2a86")) {
#                     Plotly.newPlot(
#                         '8dd8d270-357e-4ac6-aa2b-93aea07c2a86',
# ...

# %%
trader = Trader(risk_size=100, target_size=300, capital=20000, fees=5.5)

# %%
ABC04.stop = {'position': 'C', 'factor': 1.5}
ABC04.selectCriteria = 'sma21'
trader.loadportfolio(portfolio=['VALE3.SA', 'CSAN3.SA', 'UGPA3.SA'], start=start, end=end)

# %%
trader.reset()
trader._R = 200
trader._trg = 600
trader.backtest(ABC04, StopOrTarget, trail=False, updaterisk=False)
# Out:
# 2020-02-03 00:00:00: CSAN3.SA entry=81.41, stop=78.41
# Loss...
# 2020-02-10 00:00:00: CSAN3.SA price=78.41
# 2020-02-20 00:00:00: VALE3.SA entry=53.42, stop=51.455
# Loss...
# 2020-02-21 00:00:00: VALE3.SA price=51.0
# 2020-03-31 00:00:00: VALE3.SA entry=42.33, stop=37.62
# 2020-04-07 00:00:00: VALE3.SA entry=44.58, stop=37.335
# 2020-04-14 00:00:00: VALE3.SA entry=45.51, stop=41.489999999999995
# 2020-04-23 00:00:00: VALE3.SA entry=44.24, stop=40.94
# 2020-04-28 00:00:00: CSAN3.SA entry=60.73, stop=48.325
# 2020-04-28 00:00:00: UGPA3.SA entry=14.5, stop=10.809999999999999
# 2020-05-05 00:00:00: UGPA3.SA entry=14.71, stop=13.375
# 2020-05-06 00:00:00: CSAN3.SA entry=61.9, stop=56.035000000000004
# Loss...
# 2020-05-07 00:00:00: UGPA3.SA price=13.38
# 2020-05-15 00:00:00: VALE3.SA entry=49.26, stop=45.765
# 2020-05-25 00:00:00: UGPA3.SA entry=16.88, stop=14.795000000000002
# 2020-05-26 00:00:00: CSAN3.SA entry=65.41, stop=61.765
# Low capital...
# ...

# %%
trader.summary()
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        47.4074
# total_trades                                            33
# open_trades                                              6
# pnl                                                3948.88
# pnl_percent                                        19.7444
# batting_avg                                       0.444444
# sharpe                                             2.80119
# liquid_cap                                         5465.08
# total_cap                                          24788.9
# Name: summary, dtype: object

# %%
trader.summary('VALE3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        58.2353
# total_trades                                            19
# open_trades                                              2
# pnl                                                2982.19
# pnl_percent                                         14.911
# batting_avg                                       0.705882
# sharpe                                             2.57591
# Name: summary, dtype: object

# %%
trader.summary('UGPA3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        52.8889
# total_trades                                            13
# open_trades                                              4
# pnl                                                -151.22
# pnl_percent                                        -0.7561
# batting_avg                                       0.222222
# sharpe                                              2.7846
# Name: summary, dtype: object

# %%
trader.summary('CSAN3.SA')
# Out:
# period          [2019-12-30 00:00:00, 2020-12-21 00:00:00]
# avg_time_in                                        21.9091
# total_trades                                            12
# open_trades                                              1
# pnl                                                1275.94
# pnl_percent                                         6.3797
# batting_avg                                       0.545455
# sharpe                                             2.84583
# Name: summary, dtype: object
